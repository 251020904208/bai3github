# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904208/bai3github/blob/python/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall , kit , liv, bed ,bath]
print(areas)
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall, kit, "living room", liv, bed, "bathroom",bath]
print(areas)
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
house = [["hallway", hall],
         ["kitchen", kit],
         ["living room", liv]]
print(house)
print(type(house))
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]
# [11.25, 18.0, 'living room', 20.0, 10.75, 'bathroom', 9.5]
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0]]
# <class 'list'>

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
print(areas[1])
print(areas[-1])
print(areas[5])
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
eat_sleep_area = areas[3] + areas[-3]
print(eat_sleep_area)
downstairs = areas[0:6]
upstairs = areas[6:-1]
print(downstairs)
print(upstairs)
downstairs = areas[:6]
upstairs = areas[6:]
print(downstairs)
print(upstairs)
x = ["a", "b", "c"]
y = x + ["d"]
y[1] = "r"
print(y)
# Out:
# 11.25
# 9.5
# 20.0
# 28.75
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom']
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom', 9.5]
# ['a', 'r', 'c', 'd']
